# %%
# import sys
# !{sys.executable} --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %%
#https://packaging.python.org/tutorials/installing-packages/
# !pip install textstat
# Out:
# Collecting textstat
#   Downloading https://files.pythonhosted.org/packages/9b/78/a050fa0f13c04db10c891167204e2cd0c0ae1be40842a10eaf5348360f94/textstat-0.5.4.tar.gz
# Collecting pyphen (from textstat)
#   Downloading https://files.pythonhosted.org/packages/15/82/08a3629dce8d1f3d91db843bb36d4d7db6b6269d5067259613a0d5c8a9db/Pyphen-0.9.5-py2.py3-none-any.whl (3.0MB)
# Collecting repoze.lru (from textstat)
#   Downloading https://files.pythonhosted.org/packages/b0/30/6cc0c95f0b59ad4b3b9163bff7cdcf793cc96fac64cf398ff26271f5cf5e/repoze.lru-0.7-py3-none-any.whl
# Building wheels for collected packages: textstat
#   Running setup.py bdist_wheel for textstat: started
#   Running setup.py bdist_wheel for textstat: finished with status 'done'
#   Stored in directory: C:\Users\Lenovo\AppData\Local\pip\Cache\wheels\04\ac\d7\a05c0ad7825899f11eacd5f9a5a78534808c8159281e65863c
# Successfully built textstat
# Installing collected packages: pyphen, repoze.lru, textstat
# Successfully installed pyphen-0.9.5 repoze.lru-0.7 textstat-0.5.4
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 19.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
test_data = (
"Playing games has always been thought to be important to "
"the development of well-balanced and creative children; "
"however, what part, if any, they should play in the lives "
"of adults has never been researched that deeply. I believe "
"that playing games is every bit as important for adults "
"as for children. Not only is taking time out to play games "
"with our children and other adults valuable to building "
"interpersonal relationships but is also a wonderful way "
"to release built up tension."
)

# %%
import textstat
textstat.gunning_fog(test_data)
# Out:
# 15.31

# %%
import pandas as pd
openCloseData=pd.read_csv("openCloseData.csv")

# %%
openCloseData.head()
# Out:
#    Unnamed: 0    PostId   UserId  Comment  \
# 0           0  21170255     5921      102
# 1           1  38290647  1601251      102
# 2           2   6496114    52924      102
# 3           3  25982771  1968462      102
# 4           4  10142243   383479      102
#
#                                                 Body  \
# 0  <p>I tried to Google for this, but was (surpri...
# 1  <p>I am at a decision fork where i have to pic...
# 2  <p>Does anyone know of a good tool to test Sch...
# 3  <p>The <a href="http://www.postgresql.org/docs...
# 4  <p>Which frameworks would you recommend for wr...
#
#                                                Title  \
# 0  Can anyone point me to (or post) an array of e...
# 1         RESTful API with either Tomcat or Node.js?
# 2                 Tool for testing Schema.org markup
# 3               Inserting into simple Postgres views
# 4  Frameworks for Unittests for Multithreading in...
#
#                                                 Tags  Reputation  \
# 0                   <javascript><html><arrays><tags>       17527
# 1          <java><node.js><rest><tomcat><typescript>         151
# 2                      <testing><markup><schema.org>        1639
# 3                                  <sql><postgresql>        2669
# 4  <java><multithreading><unit-testing><concurrency>         245
#
#    experienceInTime                         WebsiteUrl      ...       \
# 0              1953                                NaN      ...
# 1              1425                                NaN      ...
# 2               900        http://www.agendarecife.com      ...
# 3               620  https://katrinahoffert.github.io/      ...
# 4               648                                NaN      ...
#
#   sentencesStartWithYouCount sentencesStartWithICount  shortWordCount  \
# 0                          0                        3              87
# 1                          0                        1              51
# 2                          0                        0              15
# 3                          0                        2              70
# 4                          0                        0              31
#
#    bodyWordCount  punctuationCount websiteUrlFilled  locationFilled  \
# 0            176                50                0               1
# 1            118                19                0               0
# 2             50                17                1               1
# 3            189                45                1               1
# 4             68                11                0               0
#
#    aboutMeFilled  profileImageUrlFilled  tagWeightSum
# 0              1                      0   -207.161031
# 1              0                      0   -536.990588
# 2              1                      0   -160.004636
# 3              1                      1   -188.646160
# 4              0                      0   -274.409048
#
# [5 rows x 36 columns]

# %%
# https://en.wikipedia.org/wiki/Readability
# 7	Popular readability formulas
        # 7.1	The Flesch formulas   
        # 7.2	The Dale–Chall formula
        # 7.3	The Gunning fog formula
# 7.4	Fry readability graph
# 7.5	McLaughlin's SMOG formula
# 7.6	The FORCAST formula
# 7.7	The Golub Syntactic Density Score
# 7.8	Readability and newspaper readership
# 7.9	The George Klare studies
# 7.10	Measuring coherence and organization
# 8	Advanced readability formulas
# 8.1	The John Bormuth formulas
# 8.2	The Lexile framework
# 8.3	ATOS readability formula for books
# 8.4	CohMetrix psycholinguistics measurements

# %% [markdown]
# https://pypi.org/project/textstat/#description

# %%
#https://en.wikipedia.org/wiki/Gunning_fog_index
openCloseData['gunningFog']=openCloseData['Body'].apply(textstat.gunning_fog)

# %%
#https://en.wikipedia.org/wiki/Flesch%E2%80%93Kincaid_readability_tests#Flesch_reading_ease
openCloseData['fleschReadingEase']=openCloseData['Body'].apply(textstat.flesch_reading_ease)

# %%
#https://en.wikipedia.org/wiki/Dale%E2%80%93Chall_readability_formula
openCloseData['daleChallReadabilityScore']=openCloseData['Body'].apply(textstat.dale_chall_readability_score)

# %%
#https://en.wikipedia.org/wiki/SMOG
openCloseData['smogIndex']=openCloseData['Body'].apply(textstat.smog_index)

# %%
#https://en.wikipedia.org/wiki/Coleman%E2%80%93Liau_index
openCloseData['colemanLiauIndex']=openCloseData['Body'].apply(textstat.coleman_liau_index)

# %%
openCloseData
# Out:
#         Unnamed: 0    PostId   UserId  Comment  \
# 0                0  21170255     5921      102
# 1                1  38290647  1601251      102
# 2                2   6496114    52924      102
# 3                3  25982771  1968462      102
# 4                4  10142243   383479      102
# 5                5  37381929  6369138      102
# 6                6  46328486  8643275      102
# 7                7   2893053   278976      102
# 8                8  28598980  4451853      102
# 9                9  19550361  2877026      102
# 10              10  20509479  2045232      102
# 11              11  21669902  2986231      102
# 12              12  27632785  3300593      102
# 13              13  35993468  5414125      102
# 14              14  45806272  5240975      102
# 15              15  37546012  3531612      102
# 16              16  51990948  6566572      102
# 17              17  46335751  5702166      102
# 18              18   8856822     5274      102
# 19              19  20665620   787949      102
# 20              20  27974279  1779677      102
# 21              21  40356329  4983501      102
# 22              22  21150321  3196340      102
# 23              23    995944    98726      102
# 24              24  19487970  2893545      102
# 25              25  18002869  1143880      102
# 26              26  19923216  1328595      102
# 27              27  25574935  3966123      102
# 28              28   2990544   182689      102
# 29              29  28491671  2167224      102
# ...            ...       ...      ...      ...
# 159966      159966  27680186  2394867      100
# 159967      159967  24421535  3167448      100
# 159968      159968  29249252   924646      100
# 159969      159969  31435603  3391589      100
# 159970      159970  24414076  3448011      100
# 159971      159971  24276195  1618720      100
# 159972      159972  37280892  6172013      100
# 159973      159973  27205668  4307004      100
# 159974      159974  33002929  1650436      100
# 159975      159975  35709404  4262556      100
# 159976      159976  29181808  1023390      100
# 159977      159977  25000905  3885139      100
# 159978      159978  25434961   163228      100
# 159979      159979  32637163  1213296      100
# 159980      159980  29410340  4262473      100
# 159981      159981  37721583  5757270      100
# 159982      159982  29459663   801496      100
# 159983      159983  37507867  5703494      100
# 159984      159984  33861279  4271491      100
# 159985      159985  22758869  1253486      100
# 159986      159986  33050960   437449      100
# 159987      159987  26306041   458325      100
# 159988      159988  29593309  4361951      100
# 159989      159989  27853179   438039      100
# 159990      159990  23985913  3678596      100
# 159991      159991  32113284  5027393      100
# 159992      159992  27693004  3979996      100
# 159993      159993  28749119  3396633      100
# 159994      159994  31148082  1502810      100
# 159995      159995  31211637  1787492      100
#
#                                                      Body  \
# 0       <p>I tried to Google for this, but was (surpri...
# 1       <p>I am at a decision fork where i have to pic...
# 2       <p>Does anyone know of a good tool to test Sch...
# 3       <p>The <a href="http://www.postgresql.org/docs...
# 4       <p>Which frameworks would you recommend for wr...
# 5       <p>I am trying to submit an app started by ano...
# 6       <p>I have imported both ArrayList and Integer....
# 7       <p>I'm a programmer.  I want to be a better pr...
# 8       <p>I'm trying to insert multiple rows by one m...
# 9       <pre><code>$bot = file_get_contents("http://an...
# 10      <p>This page is redirected from another page w...
# 11      <p>I want to save a function in a var in JavaS...
# 12      <p>As I know we can do the jMeter distributed ...
# 13      <p>which API can i use to translate text in Py...
# 14      <p>I want to create a procedure to clone SQL S...
# 15      <p>I trying to build a Simon game but I'm mess...
# 16      <p>I'm starting to work with Ionic and I'd lik...
# 17      <p>My biggest problem with AWS is dealing with...
# 18      <p>I am looking for a good HTML documentation ...
# 19      <p>I have a requirement where I need to show a...
# 20      <p>LinkedIn Omniauth is working on chrome and ...
# 21      <p>I'm studying Rails and have come across som...
# 22      <p>I keep getting "Type Error: str.join is not...
# 23      <p>Does anyone know of a good library for SSH ...
# 24      <p>I am unable to write following code in xcod...
# 25      <p>Anybody knows why in mobile footer looks hu...
# 26      <p>I want to make a code that generated random...
# 27      <p>I am trying to add white shadow/blur around...
# 28      <p>I was asked if I could program something fo...
# 29      <p>I have a windows 7 x64 enterprise instance ...
# ...                                                   ...
# 159966  <p>I have a CSV table with data similar to bel...
# 159967  <p>How does one use the flag options for bench...
# 159968  <p>According to <a href= http://fullcalendar.i...
# 159969  <p>First of all I understand that I can use <c...
# 159970  <p>I need to customize an error message in SQL...
# 159971  <p>Using Java's ProcessBuilder I can run an ex...
# 159972  <p>During the development of my custom <code>E...
# 159973  <p>I'm trying to optimize a SQL Server query c...
# 159974  <p>I have an activity that display map cards (...
# 159975  <p>I apologise in advance as there are a lot o...
# 159976  <p>This simple code</p> <pre><code>template&lt...
# 159977  <p>Alright so I'm testing with some SQLi on lo...
# 159978  <p>So I have a nodejs app that is using <a hre...
# 159979  <p>I have created the following type of circle...
# 159980  <p>I have a class named <code>matFactory()</co...
# 159981  <p>My configuration : RabbitMq version 3.2.4 E...
# 159982  <p>I Just installed <strong>homebrew/homebrew-...
# 159983  <p>I'm an ASP.NET developer and haven't been r...
# 159984  <p>I have a very short question that is partia...
# 159985  <p>I've been running a Gearman Job Server with...
# 159986  <p>I'm trying basically to get information out...
# 159987  <p>I have a select list and I want to change t...
# 159988  <p>Im really stuck on this one I want people t...
# 159989  <p>So I currently have this:</p> <pre><code>TE...
# 159990  <p>The scenario is:</p> <p>I have a list of pr...
# 159991  <p>I am wondering if we should clean target fo...
# 159992  <p>I have a MVC5 app and in one of my views I ...
# 159993  <p>I am working on a project with Meteor.js an...
# 159994  <p>Using LLDB (version 179.5 with XCode 4.6.3)...
# 159995  <p>I am trying to send base64 encoded email us...
#
#                                                     Title  \
# 0       Can anyone point me to (or post) an array of e...
# 1              RESTful API with either Tomcat or Node.js?
# 2                      Tool for testing Schema.org markup
# 3                    Inserting into simple Postgres views
# 4       Frameworks for Unittests for Multithreading in...
# 5               Submitting app started by other developer
# 6       cannot find symbol - ArrayList; cannot find sy...
# 7       How can the Kindle be used as a source code re...
# 8                 Insert multiple rows by one mysql query
# 9                SimpleXML not working with Yahoo Answers
# 10                                        MySql Jsp error
# 11              sending a parameter to function in a var?
# 12      jMeter distributed system testing over cloud w...
# 13                           Translation Languages Python
# 14                     User-defined table type definition
# 15       inline-block isn't working as expected with divs
# 16      Ionic 2: Can I pass a page as an argument to n...
# 17      Any editor that allows me to edit Python code ...
# 18                  HTML Documentation generator for .NET
# 19                 I would like to show list of pdf files
# 20                 Linkedin Omniauth Won't Work on Safari
# 21      Where can I find the documentation of `present...
# 22      Still not working- function: letter to next le...
# 23                                   SSH library for Java
# 24      How I set NSAttributedString object to uilabel...
# 25                  Same size text looks bigger in mobile
# 26      Generate random codes that are decrypted by th...
# 27                          Add shadow to toolbar divider
# 28             Getting started with vBulletin development
# 29      ODBC driver for Oracle on Windows 7 x64 disapp...
# ...                                                   ...
# 159966                      Python Pandas Indexing Reform
# 159967  How do you use the benchmark flags for the go ...
# 159968  How pass custom parameters to FullCalendar eve...
# 159969       Python: Modify Global list inside a function
# 159970  customize an error message in SQL server 2008 ...
# 159971  Java ProcessBuilder: capture output from scrip...
# 159972                   How to update EventSource schema
# 159973  SQL Server will not choose optimal index for q...
# 159974  Swipe animation of Fragment following the user...
# 159975             Importing font through CSS not working
# 159976  type inconsistency between std::setw() and ost...
# 159977  Output won't display if it exists more than on...
# 159978          How to import sails.js disk.db to mongodb
# 159979                One side border to circle in canvas
# 159980  Can a method be able to return different data ...
# 159981           RabbitMqadmin in order to realize unbind
# 159982            OS X Homebrew's PHP extensions location
# 159983         Can't Deploy an MVC website to Godaddy.com
# 159984      App.config connectionString change at startup
# 159985             Gearman Workers disconnect periodicaly
# 159986  YoutubeDL - How to get a status object after d...
# 159987           Knockout select options and dependencies
# 159988  mailto doesnt work with android how to solve t...
# 159989  Makefile: capture error code in rule ignore er...
# 159990  Sorting a query based on a category preference...
# 159991          Should we clean target folder after tests
# 159992  How to find which checkboxes are selected and ...
# 159993  Why Does {{#each}} Work Properly While {{#with...
# 159994  Is there a way to enable/disable a breakpoint ...
# 159995        Send base64 encoded email using CodeIgniter
#
#                                                      Tags  Reputation  \
# 0                        <javascript><html><arrays><tags>       17527
# 1               <java><node.js><rest><tomcat><typescript>         151
# 2                           <testing><markup><schema.org>        1639
# 3                                       <sql><postgresql>        2669
# 4       <java><multithreading><unit-testing><concurrency>         245
# 5       <ios><iphone><certificate><provisioning-profil...           8
# 6                              <java><arraylist><integer>           6
# 7                                  <ipad><github><kindle>        9442
# 8                                            <php><mysql>         121
# 9                                 <php><simplexml><yahoo>           1
# 10                                     <java><mysql><jsp>         423
# 11                                     <javascript><html>          46
# 12      <jmeter><performance-testing><load-testing><st...         755
# 13                             <python><api><translation>          53
# 14           <sql-server><definition><user-defined-types>          58
# 15                                            <html><css>         116
# 16                                      <angular><ionic2>           1
# 17      <python><amazon-web-services><amazon-ec2><subl...          66
# 18                                  <.net><documentation>       39068
# 19                     <c#><windows-phone-8><windows-8.1>          22
# 20                   <heroku><safari><linkedin><omniauth>         849
# 21                                  <ruby-on-rails><ruby>         779
# 22       <javascript><regex><for-loop><unicode><alphabet>         316
# 23                                <java><ssh><ssh-tunnel>        3745
# 24                                 <objective-c><uilabel>           4
# 25                                                  <css>          82
# 26                          <android><vb.net><encryption>         103
# 27                                            <html><css>          48
# 28               <php><documentation><plugins><vbulletin>        9000
# 29                                      <windows><oracle>           1
# ...                                                   ...         ...
# 159966                                      python|pandas         162
# 159967                            testing|go|benchmarking        3910
# 159968                javascript|jquery|html|fullcalendar        1286
# 159969                   python|function|global-variables         122
# 159970  sql|sql-server|sql-server-2008|exception|windo...         151
# 159971                                java|processbuilder         185
# 159972               etw|etw-eventsource|semantic-logging         105
# 159973                         sql-server|sql-server-2008           3
# 159974  android|android-fragments|android-animation|ge...         263
# 159975                                                css          16
# 159976                               c++|iostream|iomanip       26438
# 159977                                      php|mysql|sql           6
# 159978                      json|node.js|mongodb|sails.js        1608
# 159979                   javascript|html|css|html5|canvas       14758
# 159980                                java|list|arraylist         729
# 159981  linux|bash|rabbitmq|rabbitmq-exchange|rabbitmqctl           6
# 159982        php|osx|homebrew|osx-yosemite|php-extension        6318
# 159983          c#|asp.net|asp.net-mvc|deployment|godaddy         114
# 159984               c#|.net|connection-string|app-config         100
# 159985                                        php|gearman          60
# 159986                       python|python-3.x|youtube-dl        1037
# 159987                             javascript|knockout.js        1521
# 159988                                        html|mailto          21
# 159989                                     shell|makefile        1017
# 159990                                c#|asp.net-mvc|linq         110
# 159991                                               java           2
# 159992             javascript|jquery|asp.net-mvc|checkbox         270
# 159993                        javascript|meteor|spacebars          65
# 159994                                     c++|xcode|lldb        1179
# 159995                         php|codeigniter|html-email         295
#
#         experienceInTime                         WebsiteUrl        ...         \
# 0                   1953                                NaN        ...
# 1                   1425                                NaN        ...
# 2                    900        http://www.agendarecife.com        ...
# 3                    620  https://katrinahoffert.github.io/        ...
# 4                    648                                NaN        ...
# 5                      0                                NaN        ...
# 6                      0                                NaN        ...
# 7                     90                                NaN        ...
# 8                     36                                NaN        ...
# 9                     10                                NaN        ...
# 10                   308                                NaN        ...
# 11                    89                                NaN        ...
# 12                   315                                NaN        ...
# 13                   160                                NaN        ...
# 14                   734                                NaN        ...
# 15                   778                                NaN        ...
# 16                   776                                NaN        ...
# 17                   640                                NaN        ...
# 18                  1222               http://www.InfoQ.com        ...
# 19                   925    http://avinashkl.wordpress.com/        ...
# 20                   810     http://www.laurenmosenthal.com        ...
# 21                   513                                NaN        ...
# 22                     0                                NaN        ...
# 23                    46                                NaN        ...
# 24                     3                                NaN        ...
# 25                   568                                NaN        ...
# 26                   579                 http://Donthaveany        ...
# 27                     8                                NaN        ...
# 28                   249                                NaN        ...
# 29                   702                                NaN        ...
# ...                  ...                                ...        ...
# 159966               590                                NaN        ...
# 159967               170                                NaN        ...
# 159968              1300                                NaN        ...
# 159969               495                                NaN        ...
# 159970                96                                NaN        ...
# 159971               664                                NaN        ...
# 159972                40                                NaN        ...
# 159973                 0                                NaN        ...
# 159974              1127                                NaN        ...
# 159975               469                                NaN        ...
# 159976              1236                                NaN        ...
# 159977                 0                                NaN        ...
# 159978              1821          https://belmer.github.io/        ...
# 159979              1309                                NaN        ...
# 159980               136                                NaN        ...
# 159981               154                                NaN        ...
# 159982              1389                 http://thehast.com        ...
# 159983               160                                NaN        ...
# 159984               368                                NaN        ...
# 159985               755                                NaN        ...
# 159986              1865                                NaN        ...
# 159987              2080            http://www.eventday.com        ...
# 159988               118                                NaN        ...
# 159989              1590                                NaN        ...
# 159990                 6                                NaN        ...
# 159991                62                                NaN        ...
# 159992               125                                NaN        ...
# 159993               355                                NaN        ...
# 159994              1090                                NaN        ...
# 159995               975         http://www.etechbangla.com        ...
#
#        websiteUrlFilled locationFilled  aboutMeFilled  profileImageUrlFilled  \
# 0                     0              1              1                      0
# 1                     0              0              0                      0
# 2                     1              1              1                      0
# 3                     1              1              1                      1
# 4                     0              0              0                      0
# 5                     0              0              0                      1
# 6                     0              1              0                      1
# 7                     0              1              1                      0
# 8                     0              0              0                      1
# 9                     0              0              0                      1
# 10                    0              1              1                      1
# 11                    0              1              0                      1
# 12                    0              0              0                      1
# 13                    0              1              0                      1
# 14                    0              1              1                      1
# 15                    0              0              0                      1
# 16                    0              1              1                      1
# 17                    0              0              1                      1
# 18                    1              1              1                      1
# 19                    1              1              0                      1
# 20                    1              1              1                      1
# 21                    0              1              0                      1
# 22                    0              0              1                      1
# 23                    0              0              0                      0
# 24                    0              0              0                      1
# 25                    0              0              0                      0
# 26                    1              1              1                      0
# 27                    0              0              0                      1
# 28                    0              1              0                      0
# 29                    0              0              0                      0
# ...                 ...            ...            ...                    ...
# 159966                0              0              1                      0
# 159967                0              0              1                      1
# 159968                0              1              1                      1
# 159969                0              0              0                      1
# 159970                0              0              0                      1
# 159971                0              1              1                      0
# 159972                0              0              0                      1
# 159973                0              0              0                      1
# 159974                0              0              0                      0
# 159975                0              0              0                      1
# 159976                0              0              1                      1
# 159977                0              0              0                      1
# 159978                1              1              1                      0
# 159979                0              1              1                      1
# 159980                0              0              0                      1
# 159981                0              0              0                      1
# 159982                1              1              1                      0
# 159983                0              0              0                      1
# 159984                0              1              1                      1
# 159985                0              0              0                      0
# 159986                0              0              0                      0
# 159987                1              1              1                      0
# 159988                0              1              0                      1
# 159989                0              0              0                      0
# 159990                0              1              1                      1
# 159991                0              0              0                      1
# 159992                0              0              0                      1
# 159993                0              1              0                      1
# 159994                0              0              0                      0
# 159995                1              1              0                      0
#
#         tagWeightSum gunningFog  fleschReadingEase  daleChallReadabilityScore  \
# 0        -207.161031      74.89             -88.22                      14.35
# 1        -536.990588      54.66             -31.38                      12.43
# 2        -160.004636      18.80              37.64                       8.35
# 3        -188.646160      46.32             -66.24                      11.74
# 4        -274.409048      21.25              45.43                       8.34
# 5        -399.904610      16.27              62.88                       8.24
# 6        -113.965895      30.00              -1.28                       9.52
# 7        -187.476051      39.86               0.09                       9.95
# 8         -87.037127      32.10            -541.37                      12.30
# 9        -214.042539      29.82            -102.47                      14.00
# 10       -191.021221      24.19              11.59                       9.50
# 11        -99.061658      22.15              43.74                       7.61
# 12       -279.421600      16.67              73.17                       8.59
# 13       -118.706868      20.40              53.55                       8.87
# 14       -152.536482      24.45              54.22                      11.45
# 15        -81.223225      76.25            -310.55                      15.54
# 16       -379.043296      19.88              25.12                       8.34
# 17       -348.727543      20.85              64.88                       8.46
# 18        -56.162603      29.75              16.67                       9.53
# 19       -174.281656      11.36              81.12                       6.44
# 20      -1189.251398      44.74             -71.29                      12.39
# 21       -173.344283      12.91              68.81                       6.64
# 22       -245.837615      18.48             -19.52                       7.54
# 23       -107.856025      11.47              84.68                       6.86
# 24       -185.483116      33.09             -51.70                      12.59
# 25        -41.927570      16.07              40.69                       7.60
# 26       -196.601865      15.55              65.35                       7.32
# 27        -81.223225      12.29              45.12                       7.48
# 28       -161.029018      19.06              40.72                       7.88
# 29       -111.730482      21.29              49.99                       8.85
# ...              ...        ...                ...                        ...
# 159966   -218.638392      15.68              55.88                       7.26
# 159967   -140.594941      27.12              17.58                       8.59
# 159968   -379.313135      30.25             -24.09                       8.99
# 159969   -153.232714      26.73              15.65                       8.23
# 159970   -340.506072      35.23              13.96                      10.50
# 159971   -172.067459      21.16              35.31                       9.03
# 159972   -461.997268      14.18              58.11                       6.91
# 159973   -150.684896      32.30             -22.93                       9.02
# 159974   -381.020575      13.54              73.78                       7.42
# 159975    -41.927570      20.07              37.98                       7.98
# 159976   -118.010851      58.31             -79.77                      13.23
# 159977   -143.251989      47.07             -40.52                      11.17
# 159978   -496.049335      19.05              21.23                       8.50
# 159979   -272.175862      23.38              11.52                       8.27
# 159980   -118.522621      20.04              16.29                       7.46
# 159981   -562.231293      39.24             -12.07                      10.21
# 159982    -39.569496      18.11              44.78                       7.94
# 159983   -274.167498      27.04              18.05                       9.51
# 159984   -560.393698      38.18             -98.40                      12.32
# 159985   -104.839893      29.68              19.54                       8.91
# 159986   -144.224685      41.38              -5.33                      10.87
# 159987   -196.909791      59.61             -90.26                      13.52
# 159988   -106.511550      25.44               0.93                       8.86
# 159989   -154.609365      54.33             -58.79                      12.09
# 159990   -186.787759      29.49              -1.45                       8.40
# 159991    -43.853036      15.32              66.44                       8.24
# 159992   -320.250417      57.20             -89.25                      12.68
# 159993   -629.206557      45.94             -14.13                      10.83
# 159994   -389.070919      21.06              42.68                       7.98
# 159995   -193.456862      23.56              -6.50                      10.03
#
#         smogIndex  colemanLiauIndex
# 0             0.0             10.18
# 1             0.0             11.45
# 2             0.0             24.66
# 3             0.0             23.40
# 4             0.0              9.47
# 5            12.2              8.99
# 6             0.0             24.03
# 7             0.0             10.35
# 8             0.0             64.51
# 9             0.0             70.17
# 10           15.5             19.21
# 11            0.0             15.68
# 12            8.8              8.92
# 13            0.0             14.16
# 14            0.0             13.80
# 15            0.0             42.14
# 16           14.6             23.33
# 17            0.0              8.25
# 18            0.0             12.49
# 19            0.0              5.62
# 20           30.3             51.53
# 21           10.1             11.14
# 22           15.0             21.30
# 23            0.0              6.95
# 24            0.0             51.06
# 25            0.0             19.90
# 26           12.2              8.25
# 27            9.7             16.79
# 28           14.6             15.15
# 29            0.0              9.76
# ...           ...               ...
# 159966       11.9              6.97
# 159967       19.1             14.35
# 159968       23.9             22.35
# 159969        0.0             12.03
# 159970        0.0             10.75
# 159971       14.6             16.42
# 159972        0.0             14.04
# 159973       20.9             19.69
# 159974       10.4              9.21
# 159975       16.7             12.78
# 159976        0.0             20.79
# 159977        0.0             23.05
# 159978       13.8             14.34
# 159979       19.7             18.00
# 159980       17.1             20.55
# 159981       21.2             15.11
# 159982       16.3             13.76
# 159983       17.5             16.20
# 159984        0.0             48.86
# 159985       15.9             10.64
# 159986       19.9             14.06
# 159987        0.0             23.05
# 159988        0.0             23.22
# 159989        0.0             11.28
# 159990        0.0             12.26
# 159991        9.7              9.67
# 159992        0.0             17.08
# 159993        0.0             11.22
# 159994       13.7             11.44
# 159995       17.1             31.21
#
# [159996 rows x 41 columns]

# %%
print(openCloseData.shape)
openCloseData.drop(['Unnamed: 0'],inplace=True,axis=1)
print(openCloseData.shape)
# Out:
# (159996, 41)
# (159996, 40)

# %%
openCloseData.columns
# Out:
# Index(['PostId', 'UserId', 'Comment', 'Body', 'Title', 'Tags', 'Reputation',
#        'experienceInTime', 'WebsiteUrl', 'Location', 'AboutMe', 'Views',
#        'Upvotes', 'Downvotes', 'ProfileImageUrl', 'tagCount', 'closed',
#        'lowerUpperRatio', 'sentenceCount', 'firstLineLength', 'codeLength',
#        'urlCount', 'SOUrlCount', 'titleLengthInChars',
#        'countOfInterrogativeSent', 'sentencesStartWithYouCount',
#        'sentencesStartWithICount', 'shortWordCount', 'bodyWordCount',
#        'punctuationCount', 'websiteUrlFilled', 'locationFilled',
#        'aboutMeFilled', 'profileImageUrlFilled', 'tagWeightSum', 'gunningFog',
#        'fleschReadingEase', 'daleChallReadabilityScore', 'smogIndex',
#        'colemanLiauIndex'],
#       dtype='object')

# %%
#Now: 40 columns
openCloseData.to_csv('openCloseData[40cols].csv')
